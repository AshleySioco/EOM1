# %% [markdown]
# # End-of-Module Assessment 1

# %% [markdown]
# ## Instructions
#
# Please read and follow these instructions and specifications carefully.
#
# 1. This test is available from July 22 to 11:59 PM of July 27. We will only grade this test after July 27, and we will only grade it once.
# 2. This test covers Modules 2 to 4. At this point in the course, you are expected to be familiar enough with Python to use the concepts from these modules with finesse.
# 3. Unless otherwise specified, you are not allowed to use any non-standard (i.e., not in the standard library) modules for this test. We must be strict about this on principle. For example, if you use NumPy or Pandas without permission on problems which ask you to process data, we reserve the right to give your answer no credit. If you are unsure whether you are allowed to use a library, ask. (Yes, you can use the csv and json libraries.)
# 4. Answers to problems that are hard-coded, done in another program such as Excel, or go against the learning outcomes in any other manner will be given no credit. If you are unsure whether your approach to a problem goes against the learning outcomes, ask.
# 5. You are encouraged to use only the provided code cell for each number. However, if you _need_ more cells, you may add them. If you do add more cells, make sure to label them very clearly. Code cells that are not clearly labelled will not be checked.
# 6. If you are asked to output files, please write them all to the `output` folder, even if we forget to specify the ./output prefix.
# 7. If we ask you to use an input file, please find the file in the appropriate section's folder. If it is not there, let us know.
#
# Submission instructions:
# 1. Create a NEW GitHub repository. This repository is what you will submit to the Canvas assignment to indicate that you have submitted. Name your repository SECTION-IDNUM-LASTNAME-EOMA1 (e.g., A-199999-ILAGAN-EOMA1).
# 2. Upload the contents of this folder to your repository. This includes the EOMA1.ipynb file, the output folder, and all three section folders.
# 3. To officially submit your assignment, upload the link to your GitHub repository and your duly accomplished COA to the Canvas assignment (just like the normal assignments).
#
# Some notes:
# 1. Joe made some of these items, and Joben made the others. The items will likely have different conventions in the context/briefs. Please follow them carefully anyway.

# %% [markdown]
# ## Section 1: Rudimentary Data Processing (30 points)

# %% [markdown]
# ### Context
#
# One extremely common form of data is the data shared between applications. Nowadays, when applications talk to each other, they send data in the form of JSON using Hypertext Transfer Protocol (HTTP). You will learn more about this in the next module.
#
# For this section, you are to process data from Twitter's API. The results of several requests to Twitter's API about tweets with the keyword "SONA" have been pre-saved in a `.json` file called `./section1/tweets.json`. Please run the following cell to ensure that the file loads properly.

# %%
# execute this cell to load the file

import json
# If the tweets do not load properly, change this path as necessary.
tweets_file = './section1/tweets.json'

with open(tweets_file, "r") as json_file:
    tweets = json.loads(json_file.read())

# Print contents of tweets to make sure things are okay.
print(tweets)
# Out:
# [{'created_at': 'Tue Jul 28 03:25:35 +0000 2020', 'id': 1287952316029521920, 'id_str': '1287952316029521920', 'full_text': 'RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'truncated': False, 'display_text_range': [0, 130], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'watchmejayjay', 'name': 'Kuya Sir #JUNKTERRORLAWNOW', 'id': 2148463897, 'id_str': '2148463897', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1334271631, 'id_str': '1334271631', 'name': 'kai', 'screen_name': '_kyladel', 'location': 'Alaska', 'description': 'yessir i listen to hayley kiyoko', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1490, 'friends_count': 551, 'listed_count': 3, 'created_at': 'Sun Apr 07 14:38:46 +0000 2013', 'favourites_count': 46915, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 74517, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1260618870752079873/ul8OMYqw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1260618870752079873/ul8OMYqw_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1334271631/1589814512', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jul 27 11:10:15 +0000 2020', 'id': 1287706865581752321, 'id_str': '1287706865581752321', 'full_text': 'Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'truncated': False, 'display_text_range': [0, 111], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2148463897, 'id_str': '2148463897', 'name': 'Kuya Sir #JUNKTERRORLAWNOW', 'screen_name': 'watchmejayjay', 'location': '', 'description': "I'm not your Bio teacher", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1128, 'friends_count': 388, 'listed_count': 0, 'created_at': 'Tue Oct 22 06:34:00 +0000 2013', 'favourites_count': 6250, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5642, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twim ...

# %% [markdown]
# ### 1.1
#
# Print out the number of tweets.

# %%
# CODE CELL

# CODE START

print(len(tweets))

# CODE END
# Out:
# 100

# %% [markdown]
# ### 1.2
#
# Create a list variable called `tweet_texts` that contains the text of the tweets contained in `tweets`.
#
# Afterwards, print `tweet_texts`.

# %%
# CODE CELL

# CODE START
tweet_texts=[x['full_text'] for x in tweets]

print(tweet_texts)
# CODE END

# The output should look like this.
# Out:
# ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Quédate con la persona que no te deje ir a dormir sin antes decirte "decansa,soña bonito y recuerda que te quiero mucho".', 'RT @gmanews: LOOK: Pati mga health worker, sumali sa anti-SONA rally kaninang umaga sa UP Diliman. \n\nAyon sa mga dumalo, malala ang mga pro…', "RT @leamaine2019: Hello there, my Queen @mainedcm!\xa0 I'll be attending PRRD's SONA w/ leaders across the globe so I won't be able to tweet f…", 'RT @heroangel17: SONA\nState Of No Accomplishment\n\n🤭✊', 'Difficult step .\nMere liye k ...

# %% [markdown]
# ### 1.3
#
# Remove duplicate tweet text lines and save the resulting (cleaned-up) list in the same variable `tweet_texts`.

# %%
# CODE CELL

# CODE START

tweet_texts = set(tweet_texts)
tweet_texts = list(tweet_texts)
print(tweet_texts)
# CODE END

# The output should look like this.
# Out:
# ['RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', 'RT @inquirerdotnet: LOOK: Groups from different sectors gather at UP Diliman, Quezon City on Monday, July 27, to protest hours before the f…', 'Mabuti na sa UP Campus @UPSystem &amp; @CHRgovph naganap ang mga kilos-protesta sa #SONA\n\nAt HINDI sa Commonwealth Ave kung saan PERWISYO &amp; SALOT lang ang mga protesta sa aming taongbayan\n\nBAWAL dapat ang mga protesta sa lansangan\n\n#SONA2020\n#SONAgKAISA\n#SONAgkaisa2020\n#SONAtotoo', 'RT @ParladeJr: On SONA..the Chinese is in possession of the WPS, they have the arms and we dont. Tama si PRRD..my question is WHO ALLOWED t…', "RT @cnnphilippines: Globe and PLDT shares are down at the first hour of trading today. It's the first time for market players to react to P…", 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', 'RT @gmanews: LOOK: Pati mga health worker, sumali sa anti-SONA rally kaninang umaga sa UP Diliman. \n\nAyon sa mga dumalo, malala ang mga pro…', 'Nakalimang SONA na ako, di ka pa rin INSURED.\nPRES: DUTERTE\nSONA 2020 https://t.co/lAiuKKFKXJ', 'RT @rapplerdotcom: “Hindi patas ang batas sa atin.”\n\nAfter the President’s 5th SONA, Human rights lawyer and staunch admin critic Chel Diok…', 'RT @michellemmanese: SONA stands for State of Neverending Audacity 🤷\u200d♀️', 'RT @boymejo: Replay of my YouTube livestream on my reaction to the SONA esp with regard to #FranklinDrilon https://t.co/7acRwA6X6Q', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', 'RT @ANCALERTS: Senate Minority Leader Franklin Drilon, which drew ire from President Duterte during his 5th SONA, said that he had "nothing…', '@Per_sona__ おちつきましｳﾞｵｵｵｵｪｱｱｱ', 'Difficult step .\nMere liye kar lega rohit....me kar lunga sona ko step pasand he 🙂.\n\n#KahaanHumKahaanTum #Ronakshi \n #KarPika #KaranVGrover #DipikaKakar \nTum jao ghar pe sona mujhe sikha degi 😂😂😂 \nMujhe maza aaya tha 😂😂 https://t.co/aqRFuujs0I', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', '@Chaiharvest OPEN YOUR PURSE SHOW ME YOUR SONA', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@DrawzSona If its Sona, we roll with it B)', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @shujoprime: 『#週刊女性』8/4/11合併号が好評発売中！ 表紙は #ジェジュン さん☆ ソウルでの独占インタビュー＆美麗写真をお見逃しなく! #三浦春馬 さんが本誌に見せてくれた素顔の数々をグラビアで振り返ります。毎年恒例「#好きなジャニーズ #嫌いなジャ…', '@ProIndian3 @kharaa_sona_ @IndianPandaa @theexwhogothot @BrahmaandKiMaa @caustic_kanya 😯😯 billi', 'Marcos: "Many decry the lack of an elaborate and all-encompassing economic plan in yesterday\'s SONA... What PRRD declared however, loud and clear... was his government\'s readiness to lead the way out of this pandemic." | via @_katrinadomingo', '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', 'Nagnegatibo sa COVID-19 si Senate Majority Leader Juan Miguel Zubiri matapos sumailalim sa swab test. Posible daw na remnants lang ng coronavirus ang nakita sa una niyang test bago ang SONA ni Pres. Duterte.\n\nMarso nang tamaan ng COVID-19 si Zubiri pero gumaling din siya kalaunan https://t.co/YveoXwq0gT', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Duterte asks Congress to pass 21 bills during the remainder of his presid ...

# %% [markdown]
# ### 1.4
#
# We will now perform a very simple word count on the texts.
#
# We have provided a dictionary called `words_dict`. Your code in the next cell should process the tweets such that `words_dict` will contain key-value pairs where the key is a unique word and where the value is the number of times the word appears across all of the texts.
#
# For each text, remove the characters contained in the following string:
#
# `"&$@[].,'#()-\"!?’_"`
#
# Please ignore the newline (`\n`) character.

# %%
# CODE CELL
words_dict = {}

remove_chars = "&$@[].,'#()-\"!?’_"

# CODE START

tweet_texts_wochar=[]
for tweet in tweet_texts:
    for char in remove_chars:
        tweet=tweet.replace(char,'')
   
    tweet_texts_wochar.append(tweet)

print(tweet_texts_wochar)
all_words= [word.upper() for x in [tweet.split() for tweet in tweet_texts_wochar] for word in x]
all_unique_words= set(all_words)


for check in all_unique_words:
    wordcount=0
    for check_here in all_words:
        if check_here==check:
            wordcount+=1
    words_dict[check] = wordcount

          

# CODE END

# Your output should look like this.
print(words_dict)
# Out:
# ['RT ItsACsLife: the fact that this years SONA wont reach the whole nation because the only station that can reach everyone nationwide was…', 'RT Hashtagnikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', 'RT inquirerdotnet: LOOK: Groups from different sectors gather at UP Diliman Quezon City on Monday July 27 to protest hours before the f…', 'Mabuti na sa UP Campus UPSystem amp; CHRgovph naganap ang mga kilosprotesta sa SONA\n\nAt HINDI sa Commonwealth Ave kung saan PERWISYO amp; SALOT lang ang mga protesta sa aming taongbayan\n\nBAWAL dapat ang mga protesta sa lansangan\n\nSONA2020\nSONAgKAISA\nSONAgkaisa2020\nSONAtotoo', 'RT ParladeJr: On SONAthe Chinese is in possession of the WPS they have the arms and we dont Tama si PRRDmy question is WHO ALLOWED t…', 'RT cnnphilippines: Globe and PLDT shares are down at the first hour of trading today Its the first time for market players to react to P…', 'RT TOWERNamba: 【ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『JJUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤\n\nCDがあれば…', 'RT gmanews: LOOK: Pati mga health worker sumali sa antiSONA rally kaninang umaga sa UP Diliman \n\nAyon sa mga dumalo malala ang mga pro…', 'Nakalimang SONA na ako di ka pa rin INSURED\nPRES: DUTERTE\nSONA 2020 https://tco/lAiuKKFKXJ', 'RT rapplerdotcom: “Hindi patas ang batas sa atin”\n\nAfter the Presidents 5th SONA Human rights lawyer and staunch admin critic Chel Diok…', 'RT michellemmanese: SONA stands for State of Neverending Audacity 🤷\u200d♀️', 'RT boymejo: Replay of my YouTube livestream on my reaction to the SONA esp with regard to FranklinDrilon https://tco/7acRwA6X6Q', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://tco/YDt5a7f6KI \n\nThisIsOurMindanao', 'RT ANCALERTS: Senate Minority Leader Franklin Drilon which drew ire from President Duterte during his 5th SONA said that he had nothing…', 'Persona おちつきましｳﾞｵｵｵｵｪｱｱｱ', 'Difficult step \nMere liye kar lega rohitme kar lunga sona ko step pasand he 🙂\n\nKahaanHumKahaanTum Ronakshi \n KarPika KaranVGrover DipikaKakar \nTum jao ghar pe sona mujhe sikha degi 😂😂😂 \nMujhe maza aaya tha 😂😂 https://tco/aqRFuujs0I', 'RT JosephMorong: Tadah Highlights of Pres Dutertes 5th SONA gmanews https://tco/bc4vfGyRpq', 'RT quarkhenares: WHY WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'Chaiharvest OPEN YOUR PURSE SHOW ME YOUR SONA', 'serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', 'DrawzSona If its Sona we roll with it B', 'RT JaDineTrash: Her own time \nHer own thoughts \nHer own style \n\nThank you Nadine The battles you fight have always been for a bigger…', 'RT Absolutalbert: VP isnt invited to SONA \n\nDesignated Survivor', 'RT shujoprime: 『週刊女性』8/4/11合併号が好評発売中！ 表紙は ジェジュン さん☆ ソウルでの独占インタビュー＆美麗写真をお見逃しなく 三浦春馬 さんが本誌に見せてくれた素顔の数々をグラビアで振り返ります。毎年恒例「好きなジャニーズ 嫌いなジャ…', 'ProIndian3 kharaasona IndianPandaa theexwhogothot BrahmaandKiMaa caustickanya 😯😯 billi', 'Marcos: Many decry the lack of an elaborate and allencompassing economic plan in yesterdays SONA What PRRD declared however loud and clear was his governments readiness to lead the way out of this pandemic | via katrinadomingo', 'marvsmodel Maliban sa war sila ni vice nasa SONA pala siya 😁', 'Nagnegatibo sa COVID19 si Senate Majority Leader Juan Miguel Zubiri matapos sumailalim sa swab test Posible daw na remnants lang ng coronavirus ang nakita sa una niyang test bago ang SONA ni Pres Duterte\n\nMarso nang tamaan ng COVID19 si Zubiri pero gumaling din siya kalaunan https://tco/YveoXwq0gT', 'May I again reiterate my thanks to you the men and women of Congress for the effort you invested into passing that law\n\nPresident Rodrigo Roa Dutertes 5th SONA', 'Duterte asks Congress to pass 21 bills during the remainder of his presidency Only 5 were specifically designed to respond to the COVID19 crisis reports maracepeda \n\nhttps://tco/6F8GGFl7GU', 'RT HMVKawasaki: 【ジェジュン】大ヒッ ...
# {'HTTPS://TCO/ULILMRYGV4': 1, 'LINGERING': 1, 'ATAYDE': 1, 'HTTPS://TCO/DX9OESFBW2': 1, 'DILIMAN': 2, '5': 2, 'DESIGNATED': 1, 'TWEETS': 1, 'VARALA': 1, 'HOLDING': 1, 'MEN': 1, 'FUCKING': 1, 'FROM': 3, 'ACCOMPLISHMENT': 1, 'ABROAD': 1, 'MITING': 1, 'P…': 1, '4': 1, 'LOUD': 1, 'VICE': 1, 'GALIT': 1, 'PANDEMYANG': 1, 'NGA': 1, '9अगस्तविश्वआदिवासीदिवस': 1, 'MENE': 1, 'HTTPS://TCO/YDT5A7F6KI': 1, 'PROTEST': 2, 'HI': 1, 'UP': 5, 'MACOYDUBS1:': 1, 'HY': 1, 'METHOD': 1, 'DRAWZSONA': 1, 'KALABAN': 1, 'KAHAPON': 1, '650000': 1, 'SONACSO': 1, 'HARRY': 1, 'ANTES': 1, 'YARU': 1, 'OKAY': 1, 'HA': 2, 'MUST💯💯💯💯': 1, 'ATTRACTIVE': 1, 'WAG': 2, 'CAPITAL': 1, 'THREAT': 1, 'BILLI': 1, 'RESPONSE': 2, 'WITHOUT': 1, 'WOULD': 3, 'SB19TRENDSPH:': 1, 'HTTPS://TCO/PVUEZOILCJ': 1, 'BALIK': 1, 'PLDT': 1, '😜': 1, 'JULY': 1, 'VIA': 1, 'さん☆': 1, 'OFF': 1, 'REMAINDER': 1, 'LISTENING': 1, 'TADAH': 1, 'AMING': 1, 'BRATBIUSH': 1, 'GOVERNMENTS': 2, 'KEEPING': 1, 'MAKE': 1, 'NEB': 1, 'HTTPS://TCO/NIEAEXKBCU': 1, 'DESPI…': 1, 'MALACAÑANG': 1, 'WERE': 2, 'BIR': 1, 'SUMAILALIM': 1, 'PERWISYO': 1, 'ALL': 1, '2019～LOVE': 1, 'FAKE': 1, 'HOGA': 2, 'BECAUSE': 1, 'HOUR': 1, 'WOOO': 1, 'NILOCKDOWN': 1, 'CIRE41:': 1, 'CDがあれば…': 1, 'HAHAHA': 1, 'KAHAN': 1, 'OSKO': 1, 'JAO': 1, 'UY': 1, 'HASHTAGNIKKO13:': 1, 'SALOT': 1, 'PASSAGE': 2, 'PARLADEJR:': 1, 'RONAKSHI': 1, 'CONSCIOUSNESS': 1, 'SHET': 1, 'NAPANOOD': 1, 'DOING': 1, 'ARMS': 1, 'DUTER…': 1, 'COVERS～』本日入荷しました🙌': 1, 'SIYANG': 1, 'ANCALERTS:': 2, 'PUPUNTA': 1, 'KIRUIU': 1, 'DIPIKAKAKAR': 1, 'KAGA': 1, 'HAI': 1, '3SAAL': 1, 'YEARS': 1, 'STYLE': 1, 'BIRISI': 1, 'PRESIDENCY': 1, 'JOSEPH': 1, 'PLEASE': 2, 'FALAN': 1, 'KACHRA': 2, 'INYO': 1, 'PUSHED': 1, 'RECOUNTS': 1, 'IS': 5, 'NEW': 2, 'HOURS': 1, 'MESSAGE': 2, 'RIA': 1, 'DEDO': 1, 'HTTPS://TCO/SJCNU8QTUO': 1, 'PRESIDENT': 8, 'KR': 1, 'MIKEDEFENSOR:': 1, 'RUHANI': 1, 'CON': 1, 'BONITO': 1, 'RTPCR': 1, 'STIPEND': 1, 'JEEVANPARIHAR15:': 1, 'STEP': 2, 'PODUNGA': 1, 'SHOW': 1, 'REPLAY': 1, '1969ENIGMA:': 1, '表紙は': 1, 'WAGE': 1, 'NAPAKAPETTY': 1, 'STAUNCH': 1, 'PANGULO': 2, 'SIKHA': 1, 'OVER': 1, 'SOOOO': 1, 'DOWN': 1, 'LUNGA': 1, 'SOON': 1, 'OPPORTUNITIES': 1, 'RIGHTS': 2, 'KHARAASONA': 3, 'HTTPS://TCO/HKJZWDY1X5': 1, 'ELAN': 1, '\\カバーアルバムを引っさげたツアー映像🎥/': 1, 'OPEN': 1, 'HTTPS://TCO/BC4VFGYRPQ': 1, 'DDS:': 1, 'QUE': 2, 'TOWERNAMBA:': 2, 'NICEGIRL09': 1, 'BUSY': 1, 'BERNAL': 1, 'RECALL': 1, 'SARAHELAGO': 1, 'ALLOWED': 1, 'INDIVIDUALS': 1, 'LUSTRE': 1, '😊': 1, 'ERBAŞ': 1, 'PRESIDENTIAL': 1, 'UMAYOS': 1, '83000': 1, 'SL': 1, 'CURRENT': 1, 'TELLS': 1, 'EXCUSES:': 1, 'SHOOT': 1, 'WORKERS': 1, 'PROBABLY': 1, 'PALA': 2, 'BAYANIHAN': 2, 'RT': 53, 'SURE': 1, 'WAKASONA2020': 2, 'WATCHED': 1, 'DEJE': 1, 'NORMAL': 1, 'VERIVERY': 1, 'CREATIVE': 1, 'DE': 1, 'NASA': 1, 'REPUBLIK…': 1, 'ABLE': 1, 'PEHLE': 1, 'CHANDRAGUPT7': 1, 'PRRDMY': 1, 'EVANU': 1, 'SPECIFYING': 1, 'ARRESTS': 1, 'KBHI': 1, 'LEAMAINE2019:': 1, 'SUPPORT': 1, 'MALIBAN': 1, 'RIAATAYDE': 1, 'POST': 1, 'PLARIDELDLSU:': 1, '🙂': 1, 'RAPPLERDOTCOM:': 3, 'DREW': 1, 'INTO': 1, 'Ⅱ』本日入荷しました🙌': 1, 'F…': 2, 'YA': 4, 'MAINEDCM': 1, 'KU': 2, 'SCRIPT': 1, 'MANY': 1, 'ANYARE': 1, 'WE': 9, 'WAR': 2, 'TUPAD': 1, '🤷\u200d♀️': 1, 'ADDRESS': 1, 'BTPRA…': 1, 'DR…': 1, 'ITSJAYEMD:': 1, 'GUMALING': 1, 'AS': 2, 'DONT': 2, 'THREAD': 1, 'ANGRY': 1, 'CHINESE': 1, 'ACTUALLY': 1, 'TREATMENT': 1, 'SONA😢😢': 1, 'WALANG': 2, 'THIS': 7, 'LANSANGAN': 1, 'PLAYERS': 1, 'IF': 3, 'POOJA': 1, 'KO🔥GALA': 1, 'QUEZON': 1, 'LEADERS': 1, 'IKUMPARA': 1, 'おちつきましｳﾞｵｵｵｵｪｱｱｱ': 1, 'USUALLY': 1, 'STATEMENT': 1, 'KARPIKA': 1, 'BATAO': 1, 'PATI': 1, 'GATHER': 1, 'ROQUE': 1, 'LIST:': 1, 'DORMIR': 1, 'AVUNGALUKU': 1, 'FORMAL': 1, 'BEEN': 1, 'CLOSELY': 1, 'FASTNESS': 1, 'MERE': 1, 'PANDEMYA': 1, 'HIM…': 1, 'GO': 1, 'SAAN': 2, 'BEAT': 1, 'POURING': 1, 'SAID': 2, 'SEMESTER': 1, 'LE': 1, 'NI': 7, 'GIVE': 2, 'ATTENDING': 1, 'CLEAR': 2, 'SANIYOR': 1, 'REIMPOSITION': 1, 'RUINING': 1, 'HOPE': 1, 'CLARITY': 1, 'VERIVERYASC': 1, 'EFFORT': 1, 'CLEAR:': 1, 'HTTPS://TCO/HQ14YGO6LU': 1, 'DAW': 1, 'BAG ...

# %% [markdown]
# ### 1.5
#
# Now, we would like to have a list of words and counts sorted by count in descending order.
#
# Define a new list variable named `words_list` containing **tuples**, where each tuple is as follows:
#
# `(word, count)`
#
# Print the contents of `words_list`.
#
# Sample output is provided below.

# %%
# CODE CELL

# CODE START

words_list=[(keyword,words_dict[keyword]) for keyword in words_dict.keys()]

# CODE END

# The output should look like this. 
print(words_list)
# Out:
# [('HTTPS://TCO/ULILMRYGV4', 1), ('LINGERING', 1), ('ATAYDE', 1), ('HTTPS://TCO/DX9OESFBW2', 1), ('DILIMAN', 2), ('5', 2), ('DESIGNATED', 1), ('TWEETS', 1), ('VARALA', 1), ('HOLDING', 1), ('MEN', 1), ('FUCKING', 1), ('FROM', 3), ('ACCOMPLISHMENT', 1), ('ABROAD', 1), ('MITING', 1), ('P…', 1), ('4', 1), ('LOUD', 1), ('VICE', 1), ('GALIT', 1), ('PANDEMYANG', 1), ('NGA', 1), ('9अगस्तविश्वआदिवासीदिवस', 1), ('MENE', 1), ('HTTPS://TCO/YDT5A7F6KI', 1), ('PROTEST', 2), ('HI', 1), ('UP', 5), ('MACOYDUBS1:', 1), ('HY', 1), ('METHOD', 1), ('DRAWZSONA', 1), ('KALABAN', 1), ('KAHAPON', 1), ('650000', 1), ('SONACSO', 1), ('HARRY', 1), ('ANTES', 1), ('YARU', 1), ('OKAY', 1), ('HA', 2), ('MUST💯💯💯💯', 1), ('ATTRACTIVE', 1), ('WAG', 2), ('CAPITAL', 1), ('THREAT', 1), ('BILLI', 1), ('RESPONSE', 2), ('WITHOUT', 1), ('WOULD', 3), ('SB19TRENDSPH:', 1), ('HTTPS://TCO/PVUEZOILCJ', 1), ('BALIK', 1), ('PLDT', 1), ('😜', 1), ('JULY', 1), ('VIA', 1), ('さん☆', 1), ('OFF', 1), ('REMAINDER', 1), ('LISTENING', 1), ('TADAH', 1), ('AMING', 1), ('BRATBIUSH', 1), ('GOVERNMENTS', 2), ('KEEPING', 1), ('MAKE', 1), ('NEB', 1), ('HTTPS://TCO/NIEAEXKBCU', 1), ('DESPI…', 1), ('MALACAÑANG', 1), ('WERE', 2), ('BIR', 1), ('SUMAILALIM', 1), ('PERWISYO', 1), ('ALL', 1), ('2019～LOVE', 1), ('FAKE', 1), ('HOGA', 2), ('BECAUSE', 1), ('HOUR', 1), ('WOOO', 1), ('NILOCKDOWN', 1), ('CIRE41:', 1), ('CDがあれば…', 1), ('HAHAHA', 1), ('KAHAN', 1), ('OSKO', 1), ('JAO', 1), ('UY', 1), ('HASHTAGNIKKO13:', 1), ('SALOT', 1), ('PASSAGE', 2), ('PARLADEJR:', 1), ('RONAKSHI', 1), ('CONSCIOUSNESS', 1), ('SHET', 1), ('NAPANOOD', 1), ('DOING', 1), ('ARMS', 1), ('DUTER…', 1), ('COVERS～』本日入荷しました🙌', 1), ('SIYANG', 1), ('ANCALERTS:', 2), ('PUPUNTA', 1), ('KIRUIU', 1), ('DIPIKAKAKAR', 1), ('KAGA', 1), ('HAI', 1), ('3SAAL', 1), ('YEARS', 1), ('STYLE', 1), ('BIRISI', 1), ('PRESIDENCY', 1), ('JOSEPH', 1), ('PLEASE', 2), ('FALAN', 1), ('KACHRA', 2), ('INYO', 1), ('PUSHED', 1), ('RECOUNTS', 1), ('IS', 5), ('NEW', 2), ('HOURS', 1), ('MESSAGE', 2), ('RIA', 1), ('DEDO', 1), ('HTTPS://TCO/SJCNU8QTUO', 1), ('PRESIDENT', 8), ('KR', 1), ('MIKEDEFENSOR:', 1), ('RUHANI', 1), ('CON', 1), ('BONITO', 1), ('RTPCR', 1), ('STIPEND', 1), ('JEEVANPARIHAR15:', 1), ('STEP', 2), ('PODUNGA', 1), ('SHOW', 1), ('REPLAY', 1), ('1969ENIGMA:', 1), ('表紙は', 1), ('WAGE', 1), ('NAPAKAPETTY', 1), ('STAUNCH', 1), ('PANGULO', 2), ('SIKHA', 1), ('OVER', 1), ('SOOOO', 1), ('DOWN', 1), ('LUNGA', 1), ('SOON', 1), ('OPPORTUNITIES', 1), ('RIGHTS', 2), ('KHARAASONA', 3), ('HTTPS://TCO/HKJZWDY1X5', 1), ('ELAN', 1), ('\\カバーアルバムを引っさげたツアー映像🎥/', 1), ('OPEN', 1), ('HTTPS://TCO/BC4VFGYRPQ', 1), ('DDS:', 1), ('QUE', 2), ('TOWERNAMBA:', 2), ('NICEGIRL09', 1), ('BUSY', 1), ('BERNAL', 1), ('RECALL', 1), ('SARAHELAGO', 1), ('ALLOWED', 1), ('INDIVIDUALS', 1), ('LUSTRE', 1), ('😊', 1), ('ERBAŞ', 1), ('PRESIDENTIAL', 1), ('UMAYOS', 1), ('83000', 1), ('SL', 1), ('CURRENT', 1), ('TELLS', 1), ('EXCUSES:', 1), ('SHOOT', 1), ('WORKERS', 1), ('PROBABLY', 1), ('PALA', 2), ('BAYANIHAN', 2), ('RT', 53), ('SURE', 1), ('WAKASONA2020', 2), ('WATCHED', 1), ('DEJE', 1), ('NORMAL', 1), ('VERIVERY', 1), ('CREATIVE', 1), ('DE', 1), ('NASA', 1), ('REPUBLIK…', 1), ('ABLE', 1), ('PEHLE', 1), ('CHANDRAGUPT7', 1), ('PRRDMY', 1), ('EVANU', 1), ('SPECIFYING', 1), ('ARRESTS', 1), ('KBHI', 1), ('LEAMAINE2019:', 1), ('SUPPORT', 1), ('MALIBAN', 1), ('RIAATAYDE', 1), ('POST', 1), ('PLARIDELDLSU:', 1), ('🙂', 1), ('RAPPLERDOTCOM:', 3), ('DREW', 1), ('INTO', 1), ('Ⅱ』本日入荷しました🙌', 1), ('F…', 2), ('YA', 4), ('MAINEDCM', 1), ('KU', 2), ('SCRIPT', 1), ('MANY', 1), ('ANYARE', 1), ('WE', 9), ('WAR', 2), ('TUPAD', 1), ('🤷\u200d♀️', 1), ('ADDRESS', 1), ('BTPRA…', 1), ('DR…', 1), ('ITSJAYEMD:', 1), ('GUMALING', 1), ('AS', 2), ('DONT', 2), ('THREAD', 1), ('ANGRY', 1), ('CHINESE', 1), ('ACTUALLY', 1), ('TREATMENT', 1), ('SONA😢😢', 1), ('WALANG', 2), ('THIS', 7), ('LANSANGAN', 1), ('PLAYERS', 1), ('IF', 3), ('POOJA', 1), ('KO🔥GALA', 1), ('QUEZON', 1), ('LEADERS', 1), ('IKUMPARA', 1), ('おちつきましｳﾞｵｵｵｵｪｱｱｱ', 1), ('USUAL ...

# %% [markdown]
# ### 1.6
#
# Sort the list by count (which is the second element of each tuple) in descending (or reverse) order.
#
# Print the contents of the newly-sorted list `words_list`.
#
# Sample output shown below.

# %%
# CODE CELL

# CODE START
def second_element(element):
    return element[1]

words_list.sort(key=second_element, reverse=True)
# CODE END

# The output should look like this.
print(words_list)
# Out:
# [('SONA', 65), ('THE', 55), ('RT', 53), ('TO', 36), ('SA', 34), ('OF', 30), ('ANG', 20), ('NA', 19), ('AND', 14), ('NG', 14), ('5TH', 13), ('MGA', 12), ('FOR', 11), ('IN', 11), ('DUTERTE', 10), ('DUTERTES', 10), ('WE', 9), ('PRESIDENT', 8), ('MY', 8), ('WITH', 8), ('THIS', 7), ('NI', 7), ('COVID19', 7), ('THAT', 7), ('2020', 7), ('I', 6), ('A', 6), ('AMP;', 6), ('MAY', 6), ('UP', 5), ('IS', 5), ('ON', 5), ('HIS', 5), ('PA', 5), ('TAG', 5), ('YA', 4), ('SONA2020', 4), ('PRES', 4), ('THEY', 4), ('RIN', 4), ('KA', 4), ('WAY', 4), ('YOU', 4), ('FIRST', 4), ('SI', 4), ('RODRIGO', 4), ('STUDENT', 4), ('DI', 4), ('STATE', 4), ('YUNG', 4), ('KO', 4), ('ROA', 4), ('FROM', 3), ('WOULD', 3), ('KHARAASONA', 3), ('RAPPLERDOTCOM:', 3), ('IF', 3), ('ONE', 3), ('NAMAN', 3), ('BEFORE', 3), ('ME', 3), ('LIKE', 3), ('ITS', 3), ('AT', 3), ('SONAGKAISA', 3), ('DAPAT', 3), ('SILA', 3), ('THA', 3), ('EVERYONE', 3), ('DURING', 3), ('HIM', 3), ('ARAW', 3), ('LANG', 3), ('HER', 3), ('COUNCIL', 3), ('PRESS', 3), ('OWN', 3), ('CONGRESS', 3), ('GLOBE', 3), ('DILIMAN', 2), ('5', 2), ('PROTEST', 2), ('HA', 2), ('WAG', 2), ('RESPONSE', 2), ('GOVERNMENTS', 2), ('WERE', 2), ('HOGA', 2), ('PASSAGE', 2), ('ANCALERTS:', 2), ('PLEASE', 2), ('KACHRA', 2), ('NEW', 2), ('MESSAGE', 2), ('STEP', 2), ('PANGULO', 2), ('RIGHTS', 2), ('QUE', 2), ('TOWERNAMBA:', 2), ('PALA', 2), ('BAYANIHAN', 2), ('WAKASONA2020', 2), ('F…', 2), ('KU', 2), ('WAR', 2), ('AS', 2), ('DONT', 2), ('WALANG', 2), ('SAAN', 2), ('SAID', 2), ('GIVE', 2), ('CLEAR', 2), ('AJITHKUMAR', 2), ('TOTALLY', 2), ('ONLY', 2), ('LA', 2), ('OFWS', 2), ('YOUR', 2), ('GET', 2), ('NANGA', 2), ('NADINE', 2), ('WONT', 2), ('LOOK:', 2), ('SHARES', 2), ('REACT', 2), ('SENATE', 2), ('VALIMAI', 2), ('HELD', 2), ('PROVIDED', 2), ('FC', 2), ('KANYANG', 2), ('LAW', 2), ('CAN', 2), ('WHICH', 2), ('POSTSONA', 2), ('WAS', 2), ('WHY', 2), ('TAPOS', 2), ('EXECUTIVE', 2), ('ACT', 2), ('AGAIN', 2), ('OUR', 2), ('LEADER', 2), ('PROTESTA', 2), ('TE', 2), ('THALAAJITHFC', 2), ('REACH', 2), ('BILLS', 2), ('HE', 2), ('RELATED', 2), ('PERO', 2), ('MARACEPEDA', 2), ('NAKITA', 2), ('ABOUT', 2), ('THALAAJITH', 2), ('BUT', 2), ('EVEN', 2), ('ALSO', 2), ('GMANEWS:', 2), ('PARA', 2), ('HUMAN', 2), ('WHAT', 2), ('DISCUSSIONS', 2), ('CNNPHILIPPINES:', 2), ('FANS', 2), ('REAPERSZN', 2), ('REQUEST', 2), ('KAR', 2), ('DRILON', 2), ('AFTER', 2), ('AGAINST', 2), ('KATRINADOMINGO', 2), ('|', 2), ('NO', 2), ('BA', 2), ('21', 2), ('【ジェジュン】', 2), ('NGAYONG', 2), ('BHAI', 2), ('HEALTH', 2), ('TAYO', 2), ('BE', 2), ('FRANKLIN', 2), ('MUJHE', 2), ('TIME', 2), ('COVID', 2), ('AKO', 2), ('HAVE', 2), ('GROUPS', 2), ('EARLIER', 2), ('THROUGH', 2), ('KUNG', 2), ('ZUBIRI', 2), ('TWEET', 2), ('PRESIDENTS', 2), ('UPDATE', 2), ('NATION', 2), ('HINDI', 2), ('HERE', 2), ('MABUTI', 2), ('COVERS', 2), ('PERSONA', 2), ('SAME', 2), ('AFTERNOON', 2), ('PAGE', 2), ('SABI', 2), ('SIYA', 2), ('MATAPOS', 2), ('TAYONG', 2), ('TEST', 2), ('PANDEMIC', 2), ('HTTPS://TCO/ULILMRYGV4', 1), ('LINGERING', 1), ('ATAYDE', 1), ('HTTPS://TCO/DX9OESFBW2', 1), ('DESIGNATED', 1), ('TWEETS', 1), ('VARALA', 1), ('HOLDING', 1), ('MEN', 1), ('FUCKING', 1), ('ACCOMPLISHMENT', 1), ('ABROAD', 1), ('MITING', 1), ('P…', 1), ('4', 1), ('LOUD', 1), ('VICE', 1), ('GALIT', 1), ('PANDEMYANG', 1), ('NGA', 1), ('9अगस्तविश्वआदिवासीदिवस', 1), ('MENE', 1), ('HTTPS://TCO/YDT5A7F6KI', 1), ('HI', 1), ('MACOYDUBS1:', 1), ('HY', 1), ('METHOD', 1), ('DRAWZSONA', 1), ('KALABAN', 1), ('KAHAPON', 1), ('650000', 1), ('SONACSO', 1), ('HARRY', 1), ('ANTES', 1), ('YARU', 1), ('OKAY', 1), ('MUST💯💯💯💯', 1), ('ATTRACTIVE', 1), ('CAPITAL', 1), ('THREAT', 1), ('BILLI', 1), ('WITHOUT', 1), ('SB19TRENDSPH:', 1), ('HTTPS://TCO/PVUEZOILCJ', 1), ('BALIK', 1), ('PLDT', 1), ('😜', 1), ('JULY', 1), ('VIA', 1), ('さん☆', 1), ('OFF', 1), ('REMAINDER', 1), ('LISTENING', 1), ('TADAH', 1), ('AMING', 1), ('BRATBIUSH', 1), ('KEEPING', 1), ('MAKE', 1), ('NEB', 1), ('HTTPS://TCO/NIEAEXKBCU', 1), ('DESPI…', 1), ('MALACAÑANG', 1), ('BIR', 1), ('SUMAILA ...

# %% [markdown]
# ### 1.7
#
# Print out the top 5 words (based on count).
#
# Take note of the formatting below (i.e. one line per print output).
#
# Sample output shown below.

# %%
# CODE CELL

# CODE START

for i in range(5):
    print(i+1,f' {words_list[i]}')

# CODE END

# The output should look like this.
# Out:
# 1  ('SONA', 65)
# 2  ('THE', 55)
# 3  ('RT', 53)
# 4  ('TO', 36)
# 5  ('SA', 34)

# %% [markdown]
# ### 1.8
#
# Write a new csv file `./output/wordcount.csv` with format like so:
#
# `word,count`
# `SONA,65`
# `THE,55`
# `RT,53`
# `TO,36`
# `SA,34`
# `...`

# %%
# CODE CELL
import csv
import json

# CODE START
words_list_str='''word,count
'''
for x in words_list:
    words_list_str+=f'{x[0]},{x[1]}'+'\n'
    
with open('./output/wordcount.csv', 'w', encoding='utf-8') as csvfile:
    csvfile.write(words_list_str)

# CODE END

# %%
#CELL TO CHECK IF FILE CONTENTS ARE THE SAME
import csv

#placing contents into list
my_list=[]
with open('./output/wordcount.csv', 'r',encoding='utf-8') as mycsv:
    my_for_list=csv.reader(mycsv)
    
    my_list=[r for r in my_for_list]
        



with open('./section1/wordcount-test.csv','r',encoding='utf-8') as samplecsv:
    sample_for_list=csv.reader(samplecsv)
    
    sample_list=[r for r in sample_for_list]
        
#checking if lists have same content
issame=[]
for i in my_list:
    if i==0 and i==['word','count']:
        issame.append(1)
    if i in sample_list:
        issame.append(1)
    else:
        issame.append(0)
for j in sample_list:
    if j in my_list:
        issame.append(1)
    else:
        issame.append(0)
all(issame)
# Out:
# True

# %% [markdown]
# Perform a `diff` or `fc` operation between your output file and the file named `wordcount-test.csv` which should be included in `section1`. Make sure there are no differences.
#
# **IMPORTANT**: Please make sure that you submit wordcount.csv along with the rest of your files.

# %% [markdown]
# ## Section 2: Reports for the Registrar (55 points)

# %% [markdown]
# ### Context
#
# Data is rarely in the form in which you want it. In this section of the assessment, you are doing consulting work for Ateneo's Office of the Registrar. They managed to collect the enlistment data for 4410 students through a Google Form. The form was not designed in such a way that the collected data is immediately usable, so they hired you to process their raw data into more appropriate forms.
#
# Please run the following cell to load the file.

# %%
# execute this cell to load the file
import json

file_path = './section2/student-enrollment-data.json'

with open(file_path, 'r') as f:
    student_data = json.load(f)
    
# Print the first few items of this file to check that it worked properly
# Please infer and understand the schema of this file.
print(student_data[:3])
# Out:
# [{'enlistment': [{'course code': 'UK 60', 'section': 'A'}, {'course code': 'GF 24', 'section': 'B'}, {'course code': 'ME 40', 'section': 'B'}, {'course code': 'VY 44', 'section': 'D'}, {'course code': 'EN 94', 'section': 'B'}], 'id': '201001', 'paid': True, 'school': 'SOSE', 'year level': 2}, {'enlistment': [{'course code': 'EQ 61', 'section': 'D'}, {'course code': 'UZ 22', 'section': 'B'}, {'course code': 'KS 36', 'section': 'B'}, {'course code': 'VH 63', 'section': 'A'}, {'course code': 'IW 81', 'section': 'C'}], 'id': '211002', 'paid': True, 'school': 'JGSOM', 'year level': 1}, {'enlistment': [{'course code': 'WE 15', 'section': 'D'}, {'course code': 'ZP 68', 'section': 'A'}, {'course code': 'GI 78', 'section': 'A'}, {'course code': 'GK 72', 'section': 'C'}, {'course code': 'FA 24', 'section': 'D'}, {'course code': 'UJ 28', 'section': 'A'}], 'id': '201003', 'paid': True, 'school': 'JGSOM', 'year level': 2}]

# %% [markdown]
# ### 2.1
#
# The first report the Registrar needs is a summary of all courses being offered. They want this report in the form of a **dictionary** whose keys are unique course codes and whose values are dictionaries with a single key-value pair describing the sections available for that course code.
#
# Here is the schema of the desired output:
#
# `{`
# &nbsp;&nbsp;&nbsp;&nbsp;`course_code: {`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"sections": [sections]`
# &nbsp;&nbsp;&nbsp;&nbsp;`}`
# `}`
#
# A dictionary called `courses` is provided to you in the following cell. Using `student_data`, populate `courses` with the data the Registrar needs.
#
# Dump this file as `./output/courses-output.json`.
#
# Additional specifications:
# 1. Sort the list of sections alphabetically.
#
# Sample output is provided in `./section2/courses-sample-output.json`.

# %%
# CODE CELL
import json
courses = {}

# CODE START

file_path = './section2/student-enrollment-data.json'

with open(file_path, 'r') as f:
    student_data = json.load(f)

list_enlistments= [x['enlistment'] for x in student_data]
course_codes=list(set([y['course code'] for x in list_enlistments for y in x]))

list_course_dict=[d for e in list_enlistments for d in e]

for check in course_codes:
    sections_list=[]
    for check_here in list_course_dict:
        if check_here['course code']==check and check_here['section'] not in sections_list:
            sections_list.append(check_here['section'])
    sections_list.sort()
    courses[check]={'sections':sections_list}

with open('./output/courses-output.json', 'w') as f:
    json.dump(courses,f, indent=4, sort_keys=True)
# CODE END

# The output should look like this.
print(courses)
# Out:
# {'UK 70': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'ZJ 82': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'GK 72': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'RT 81': {'sections': ['A']}, 'QR 51': {'sections': ['A']}, 'FA 24': {'sections': ['A', 'B', 'C', 'D']}, 'UZ 22': {'sections': ['A', 'B', 'C']}, 'UJ 28': {'sections': ['A', 'B', 'C']}, 'SN 88': {'sections': ['A']}, 'GV 12': {'sections': ['A']}, 'PG 71': {'sections': ['A', 'B', 'C']}, 'HW 19': {'sections': ['A']}, 'KD 33': {'sections': ['A']}, 'TT 59': {'sections': ['A', 'B']}, 'MC 25': {'sections': ['A', 'B']}, 'TS 66': {'sections': ['A']}, 'GM 72': {'sections': ['A']}, 'AI 41': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'YB 54': {'sections': ['A', 'B', 'C', 'D']}, 'VH 63': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'ME 40': {'sections': ['A', 'B', 'C']}, 'OG 37': {'sections': ['A', 'B', 'C', 'D']}, 'VY 44': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'LV 41': {'sections': ['A', 'B', 'C', 'D']}, 'FX 96': {'sections': ['A']}, 'KC 22': {'sections': ['A', 'B', 'C', 'D']}, 'LJ 29': {'sections': ['A', 'B']}, 'WE 15': {'sections': ['A', 'B', 'C', 'D']}, 'BN 85': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'KS 36': {'sections': ['A', 'B', 'C']}, 'YD 55': {'sections': ['A', 'B', 'C', 'D']}, 'ZP 68': {'sections': ['A']}, 'EQ 61': {'sections': ['A', 'B', 'C', 'D']}, 'GF 24': {'sections': ['A', 'B', 'C']}, 'YS 74': {'sections': ['A', 'B', 'C']}, 'HK 84': {'sections': ['A']}, 'KD 10': {'sections': ['A', 'B', 'C']}, 'FZ 18': {'sections': ['A']}, 'MU 79': {'sections': ['A', 'B']}, 'UK 60': {'sections': ['A']}, 'YQ 49': {'sections': ['A', 'B']}, 'VC 62': {'sections': ['A', 'B', 'C']}, 'GI 78': {'sections': ['A']}, 'SE 79': {'sections': ['A', 'B', 'C', 'D']}, 'VS 18': {'sections': ['A']}, 'ZB 82': {'sections': ['A']}, 'AX 43': {'sections': ['A']}, 'IW 81': {'sections': ['A', 'B', 'C']}, 'EN 94': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}}

# %% [markdown]
# ### 2.2
#
# The second report the Registrar needs is a _class list_ of every section. They want this report in the form of a **dictionary** whose keys are the course code and whose values are dictionaries describing the sections of that course code. Each section dictionary has two key-value pairs:
# 1. Key: "section"; Value: Section letter
# 2. Key: "class list"; Value: [id numbers]
#
# Here is the schema of the desired output:
# `{`
# &nbsp;&nbsp;&nbsp;&nbsp;`course_code: [{`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"section": section_letter,`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"class list": [id_numbers]`
# &nbsp;&nbsp;&nbsp;&nbsp;`}]`
# `}`
#
# A dictionary called `class_lists` is provided to you. Using `student_data`, populate `class_lists` with the data that the Registrar needs.
#
# Dump this file as `./output/class-lists.json`.
#
# Additional specifications:
# 1. Sort the list of ID numbers. No need to convert them to int, just sort them in place with `.sort()`.
# 2. Do not reference the `courses` dictionary from Item 2.1 directly. This cell should be able to run independently of Item 2.1. You may, however, reuse your code by copy-pasting it here if you find that it will help.
#
# Sample output is provided in `./section2/class-lists-sample-output.json`.

# %%
# CODE CELL
import json
class_lists = {}

# CODE START

file_path = './section2/student-enrollment-data.json'

with open(file_path, 'r') as f:
    student_data = json.load(f)

list_enlistments= [x['enlistment'] for x in student_data]
course_codes=list(set([y['course code'] for x in list_enlistments for y in x]))

list_course_dict=[d for e in list_enlistments for d in e]

for check in course_codes:
    class_lists[check]=[]
    sections_list=[]
    for check_here in list_course_dict:
        if check_here['course code']==check and check_here['section'] not in sections_list:
            sections_list.append(check_here['section'])
    sections_list.sort()
    for section in sections_list:
        classlist=[]
        for i in student_data:
            if {'course code': check, 'section': section} in i['enlistment']:
                classlist.append(i['id'])
        class_lists[check].append({'section':section,'class list':classlist})

print(class_lists)

with open('./output/class-lists.json', 'w') as f:
    json.dump(class_lists,f, indent=4, sort_keys=True)

# CODE END

# The output should look like this.
# This code is not supposed to be able to run in your notebook; it is fine to remove it if you will begin working.
# Out:
# {'UK 70': [{'section': 'A', 'class list': ['201045', '211092', '211360', '211399', '211406', '211409', '211454', '201482', '211520', '211546', '201548', '211575', '211633', '211650', '201766', '211784', '211847', '201951', '211952', '211960', '202011', '202055', '202127', '212133', '202248', '202315', '202327', '202346', '212469', '202503', '202535', '212578', '202614', '202620', '202748', '212855', '202896', '203092', '203099', '203103', '213106', '213118', '213250', '213268', '213348', '213390', '213404', '203407', '203409', '203516', '213541', '213554', '213629', '203763', '213820', '203838', '213887', '203944', '213954', '213955', '213958', '213996', '204044', '214092', '204118', '204168', '214206', '214214', '204229', '204366', '204479', '214494', '204527', '204612', '214791', '204799', '204935', '205028', '205054', '215130', '205156', '215243', '205353', '215394']}, {'section': 'B', 'class list': ['211036', '211112', '201147', '201195', '201198', '201236', '201246', '201282', '201293', '201334', '211345', '211394', '211536', '201560', '201566', '211573', '211606', '201622', '201649', '211670', '211719', '201755', '211776', '211778', '201802', '211849', '201879', '201926', '201994', '202000', '202087', '212102', '212124', '202173', '212195', '202197', '212277', '202348', '202354', '202362', '202373', '212402', '202411', '202493', '212537', '212539', '212668', '212673', '202698', '202729', '202753', '212825', '202879', '202914', '212933', '212953', '202962', '203043', '203046', '213093', '213128', '203137', '213140', '213210', '203236', '203260', '203299', '213488', '203538', '213576', '213650', '203676', '203690', '203781', '213857', '213866', '203892', '213918', '213934', '213945', '203951', '203959', '214020', '204024', '204028', '204033', '204048', '204127', '214166', '204175', '214239', '204269', '204342', '204372', '204424', '204434', '204435', '204472', '214497', '204522', '204564', '214573', '214578', '214629', '214644', '214671', '214762', '214773', '214776', '214811', '204861', '204902', '204909', '204987', '205046', '205117', '205137', '205180', '215203', '205228', '205259', '205261', '215385', '215396']}, {'section': 'C', 'class list': ['201067', '201108', '201170', '201218', '211232', '211244', '201262', '211263', '211317', '201320', '201321', '201365', '211384', '211433', '201442', '211456', '211477', '201486', '201508', '201514', '211582', '211594', '211627', '211655', '211674', '211723', '211823', '211876', '201883', '201914', '211958', '202022', '202134', '212151', '212163', '212268', '212270', '202320', '212356', '202429', '202513', '212601', '202617', '212725', '202950', '202994', '212995', '203054', '213073', '213098', '203147', '213191', '203193', '203330', '213368', '213481', '213567', '213611', '213648', '213687', '213736', '213794', '213833', '203844', '213869', '213896', '203912', '203935', '204018', '214045', '214062', '204099', '214157', '214167', '204178', '204211', '214285', '214298', '204314', '214378', '214399', '214403', '204453', '214459', '214480', '214505', '214520', '204521', '214530', '214550', '214592', '204687', '204695', '214704', '204742', '204764', '214792', '204805', '214841', '214878', '204879', '204881', '214889', '204892', '214895', '204899', '214975', '214981', '214982', '215051', '205088', '205134', '205145', '215160', '215206', '205242', '205271', '205280', '205363']}, {'section': 'D', 'class list': ['211024', '211028', '201029', '211037', '201093', '211157', '201212', '201275', '201316', '201335', '201378', '201427', '201481', '211549', '211590', '211600', '201613', '211641', '211642', '211700', '201711', '211749', '211838', '201967', '211986', '212131', '202157', '202205', '202235', '212256', '212353', '212391', '212431', '212437', '212440', '212451', '202491', '202530', '212533', '212716', '212721', '212738', '212795', '212858', '202860', '202866', '212918', '203000', '203059', '203134', '203135', '213166', '203383', '213463', '213467', '213518', '203590', '213737', '2140 ...

# %% [markdown]
# ## Section 3: Payroll (65 points)

# %% [markdown]
# ### Context
#
# A startup decides to avoid hiring regular employees for now. Instead, they have been engaging consultants and interns to support them in their current operations. There are not a lot of people, but preparation is tedious.
#
# All consultants and interns get paid at the end of the month.
#
# Interns are expected to render 20 hours of work each month. The actual number of hours worked by each intern is then prorated against the monthly fee stated in their contract. For example, if an intern works 20 hours, then the disbursement will be 100%. If another intern works for only 11, the payout will be 11/20 or 55%.
#
# If interns go overtime in the month, they get a premium of 200% on their hourly rate for anything in excess of 20 hours. The hourly rate is computed as follows:
#
# *hourly rate = contracted monthly fee / 20*
#
# The startup works on an honesty system. In lieu of timesheets, each intern is given a link to Google Forms where they specify their temporary company ID and the number of hours they rendered for the month. All entries are then logged in an associated Google Sheets document. Human Resources then is able to export the spreadsheet into a CSV that looks like so (for the month of July, 2021, as contained in the file **./section3/interns-timelog-july-2021.csv**):
#
# ```
# id,hours_rendered
# 2021001,20
# 2021002,17
# 2021003,16
# 2021004,15
# 2021005,16
# 2021006,18
# 2021007,17
# 2021008,17
# 2021009,15
# 2021010,18
# 2021011,16
# 2021012,20
# 2021013,18
# 2021014,22
# 2021015,20
# 2021016,25
# 2021017,20
# 2021018,17
# 2021019,20
# 2021020,18
# ```
#
# At the company's discretion, certain employees are given work-from-home (WFH) privileges. If an intern has been tagged to be given a WFH allowance, an additional P300 is given.
#
# In addition, the intern gets to designate one of two banks (BPI, BDO) for payroll crediting.
#
# The intern masterfile, saved from a central database as csv, is shown below:
#
# ```
# id,bank,account_number,monthly_fee,wfh
# 2021001,BPI,1093 5000 5001,4500,Y
# 2021002,BPI,1093 5000 5002,3500,Y
# 2021003,BPI,1093 5000 5003,4500,Y
# 2021004,BPI,1093 5000 5004,4500,Y
# 2021005,BPI,1093 5000 5005,6000,Y
# 2021006,BPI,1093 5000 5006,4500,Y
# 2021007,BPI,1093 5000 5007,5000,Y
# 2021008,BPI,1093 5000 5008,4500,Y
# 2021009,BPI,1093 5000 5009,4500,N
# 2021010,BPI,1093 5000 5010,6000,N
# 2021011,BPI,1093 5000 5011,4500,N
# 2021012,BPI,1093 5000 5012,3500,N
# 2021013,BPI,1093 5000 5013,4500,N
# 2021014,BPI,1093 5000 5014,4500,N
# 2021015,BPI,1093 5000 5015,5000,Y
# 2021016,BPI,1093 5000 5016,4500,Y
# 2021017,BPI,1093 5000 5017,6000,Y
# 2021018,BPI,1093 5000 5018,3500,Y
# 2021019,BPI,1093 5000 5019,4500,Y
# 2021020,BPI,1093 5000 5020,4500,Y
# ```
#
# Consultants are paid in full (with no accounting for time); however, their take home pay is their contracted monthly fee less 10%. For example, if one consultant's gross pay is P100,000, the amount to be disbursed is P100,000 less 10% = P90,000. For another consultant that insists on P100,000 as net amount, it will be the company's burden to shoulder the taxes; this arrangement is commonly known as "grossing up". In the case of gross-up, if the disbursement needs to preserve P100,000.00, the contracted monthly fee is P111,111.11.
#
# Similar to interns, certain consultants are provided WFH allowance.
#
# The consultant masterlist is shown below:
#
# ```
# tin,bank,account_number,monthly_fee,wfh
# 151-500-200-000,BPI,1093 5000 6001,100000,Y
# 151-500-201-000,BPI,1093 5000 6002,50000,Y
# 151-500-202-000,BDO,0078 0000 0001,111111.11,Y
# 151-500-203-000,BPI,1093 5000 6004,100000,Y
# 151-500-204-000,BPI,1093 5000 6005,65000,Y
# 151-500-205-000,BPI,1093 5000 6006,130000,Y
# 151-500-206-000,BDO,0078 0000 0002,50000,Y
# 151-500-207-000,BDO,0078 0000 0003,45000,Y
# 151-500-208-000,BPI,1093 5000 6007,45000,N
# 151-500-209-000,BPI,1093 5000 6008,60000,N
# 151-500-210-000,BPI,1093 5000 6009,45000,N
# ```

# %% [markdown]
# ### 3.1

# %% [markdown]
# #### 3.1.1
#
# Write a function **get_utilization** with an argument **hours_rendered** and returns utilization (not percentage).

# %%
# CODE CELL
#used new file as reference

# CODE START
def get_utilization(hours_rendered):
    
    return hours_rendered/20
# CODE END

# %% [markdown]
# #### 3.1.2
#
# Write a function **get_pay** with four arguments: **monthly_fee**, **hours_rendered**, **overtime**, and **wfh_allowance**. It then returns the computed takehome pay as float.
#
# This function will presumably call **get_utilization**.

# %%
# CODE CELL

# CODE START
def get_pay(monthly_fee, hours_rendered, overtime_pay, wfh_allowance):
    if hours_rendered>20:
        pay= monthly_fee+overtime_pay+wfh_allowance
    else:
        
        pay=monthly_fee*get_utilization(hours_rendered)+overtime_pay+wfh_allowance
    return pay
# CODE END

# %% [markdown]
# #### 3.1.3
#
# Write a function **get_overtime_pay** that accepts **hours_rendered** and **monthly_fee** as parameters and then returns the amount of overtime to credit to the intern.

# %%
# CODE CELL

# CODE START
def get_overtime_pay(monthly_fee,hours_rendered):
    if hours_rendered>20:
        return (monthly_fee/20)*2*(hours_rendered-20)
        
    else:
        return float(0)
# CODE END
get_overtime_pay(4500,22)
# Out:
# 900.0

# %% [markdown]
# You may run the cell below to test your code.

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it!

# Expected output: 2250.0
get_overtime_pay(4500,25)
# Out:
# 2250.0

# %% [markdown]
# ### 3.2: For Interns

# %% [markdown]
# #### 3.2.1
#
# Create a list variable named `raw_log` that contains dictionaries (or ordered dictionaries if you use the DictReader method of the Python csv module) for each entry in the time-and-attendance log file **./section3/interns-timelogs-july2021.csv**.

# %%
# CODE CELL
import csv

# CODE START
raw_log=[]
with open('./section3/interns-timelogs-july2021.csv','r') as csvfile:
    logs=csv.DictReader(csvfile)

    for r in logs:
        raw_log.append(r)
# CODE END
# sample dump of raw_log in interactive mode
raw_log
# Out:
# [{'id': '2021001', 'hours_rendered': '20'},
#  {'id': '2021002', 'hours_rendered': '17'},
#  {'id': '2021003', 'hours_rendered': '16'},
#  {'id': '2021004', 'hours_rendered': '15'},
#  {'id': '2021005', 'hours_rendered': '16'},
#  {'id': '2021006', 'hours_rendered': '18'},
#  {'id': '2021007', 'hours_rendered': '17'},
#  {'id': '2021008', 'hours_rendered': '17'},
#  {'id': '2021009', 'hours_rendered': '15'},
#  {'id': '2021010', 'hours_rendered': '18'},
#  {'id': '2021011', 'hours_rendered': '16'},
#  {'id': '2021012', 'hours_rendered': '20'},
#  {'id': '2021013', 'hours_rendered': '18'},
#  {'id': '2021014', 'hours_rendered': '22'},
#  {'id': '2021015', 'hours_rendered': '20'},
#  {'id': '2021016', 'hours_rendered': '25'},
#  {'id': '2021017', 'hours_rendered': '20'},
#  {'id': '2021018', 'hours_rendered': '17'},
#  {'id': '2021019', 'hours_rendered': '20'},
#  {'id': '2021020', 'hours_rendered': '18'}]

# %% [markdown]
# #### 3.2.2
#
# To retrieve details about individual interns quickly, it's best that we store intern data in a dictionary. This way, we simply lookup the details of the intern by key (in this case, the **id**).
#
# Create a dictionary variable named **interns_master_dict** that contains dictionaries for each entry in the intern master file file **./section3/interns-masterlist.csv**.

# %%
# CODE CELL
import csv

# CODE START
interns_master_dict={}

with open('./section3/interns_masterlist.csv','r') as f:
    maslist=csv.DictReader(f)

    for r in maslist:
        interns_master_dict[r['id']]={'bank':r['bank'],'account_number':r['account_number'],'monthly_fee':r['monthly_fee'],'wfh':r['wfh']}

# CODE END

# sample dump of raw_log in interactive mode
interns_master_dict
# Out:
# {'2021001': {'bank': 'BPI',
#   'account_number': '1093 5000 5001',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021002': {'bank': 'BPI',
#   'account_number': '1093 5000 5002',
#   'monthly_fee': '3500',
#   'wfh': 'Y'},
#  '2021003': {'bank': 'BPI',
#   'account_number': '1093 5000 5003',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021004': {'bank': 'BPI',
#   'account_number': '1093 5000 5004',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021005': {'bank': 'BPI',
#   'account_number': '1093 5000 5005',
#   'monthly_fee': '6000',
#   'wfh': 'Y'},
#  '2021006': {'bank': 'BPI',
#   'account_number': '1093 5000 5006',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021007': {'bank': 'BPI',
#   'account_number': '1093 5000 5007',
#   'monthly_fee': '5000',
#   'wfh': 'Y'},
#  '2021008': {'bank': 'BPI',
#   'account_number': '1093 5000 5008',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021009': {'bank': 'BPI',
#   'account_number': '1093 5000 5009',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021010': {'bank': 'BPI',
#   'account_number': '1093 5000 5010',
#   'monthly_fee': '6000',
#   'wfh': 'N'},
#  '2021011': {'bank': 'BPI',
#   'account_number': '1093 5000 5011',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021012': {'bank': 'BPI',
#   'account_number': '1093 5000 5012',
#   'monthly_fee': '3500',
#   'wfh': 'N'},
#  '2021013': {'bank': 'BPI',
#   'account_number': '1093 5000 5013',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021014': {'bank': 'BPI',
#   'account_number': '1093 5000 5014',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021015': {'bank': 'BPI',
#   'account_number': '1093 5000 5015',
#   'monthly_fee': '5000',
#   'wfh': 'Y'},
#  '2021016': {'bank': 'BPI',
#   'account_number': '1093 5000 5016',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021017': {'bank': 'BPI',
#   'account_number': '1093 5000 5017',
#   'monthly_fee': '6000',
#   'wfh': 'Y'},
#  '2021018': {'bank': 'BPI',
#   'account_number': '1093 5000 5018',
#   'monthly_fee': '3500',
#   'wfh': 'Y'},
#  '2021019': {'bank': 'BPI',
#   'account_number': '1093 5000 5019',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021020': {'bank': 'BPI',
#   'account_number': '1093 5000 5020',
#   'monthly_fee': '4500',
#   'wfh': 'Y'}}

# %% [markdown]
# #### 3.2.3
#
# Create a new list variable **interns_payroll** based on raw_logs but with an additional key takehome_pay for each dictionary entry.

# %%
# CODE CELL

# CODE START
interns_payroll=[]



for k,v in interns_master_dict.items():
    
    indiv_dict={}
    indiv_dict['id']=k
    for h in raw_log:
        if h['id']==k:
            hours_rendered=int(h['hours_rendered'])
    indiv_dict['hours_rendered']=h['hours_rendered'] #sample output has string for hours_rendered
    
    
    monthly_fee=int(v['monthly_fee'])
    indiv_dict['monthly_fee']=monthly_fee
    
    for i in raw_log:
        if i['id']==k:
            prorated_pay=int(v['monthly_fee'])*get_utilization(int(i['hours_rendered']))
    indiv_dict['prorated_pay']=prorated_pay
    
    for j in raw_log:
        if j['id']==k:
            overtime_pay=get_overtime_pay(int(v['monthly_fee']),int(j['hours_rendered']))
           
    indiv_dict['overtime_pay']=overtime_pay
    
    if v['wfh']=='Y':
        wfh_allowance = 300
        indiv_dict['wfh_allowance']=wfh_allowance
    else:
        wfh_allowance = 0
    
    takehome_pay=get_pay(monthly_fee, hours_rendered, overtime_pay, wfh_allowance)
    
    indiv_dict['takehome_pay']=takehome_pay
    interns_payroll.append(indiv_dict)

# CODE END   
# sample dump of payroll in interactive mode
interns_payroll
# Out:
# [{'id': '2021001',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4500.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4800.0},
#  {'id': '2021002',
#   'hours_rendered': '18',
#   'monthly_fee': 3500,
#   'prorated_pay': 2975.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3275.0},
#  {'id': '2021003',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 3600.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3900.0},
#  {'id': '2021004',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 3375.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3675.0},
#  {'id': '2021005',
#   'hours_rendered': '18',
#   'monthly_fee': 6000,
#   'prorated_pay': 4800.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 5100.0},
#  {'id': '2021006',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4350.0},
#  {'id': '2021007',
#   'hours_rendered': '18',
#   'monthly_fee': 5000,
#   'prorated_pay': 4250.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4550.0},
#  {'id': '2021008',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 3825.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4125.0},
#  {'id': '2021009',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 3375.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 3375.0},
#  {'id': '2021010',
#   'hours_rendered': '18',
#   'monthly_fee': 6000,
#   'prorated_pay': 5400.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 5400.0},
#  {'id': '2021011',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 3600.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 3600.0},
#  {'id': '2021012',
#   'hours_rendered': '18',
#   'monthly_fee': 3500,
#   'prorated_pay': 3500.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 3500.0},
#  {'id': '2021013',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 4050.0},
#  {'id': '2021014',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4950.0,
#   'overtime_pay': 900.0,
#   'takehome_pay': 5400.0},
#  {'id': '2021015',
#   'hours_rendered': '18',
#   'monthly_fee': 5000,
#   'prorated_pay': 5000.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 5300.0},
#  {'id': '2021016',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 5625.0,
#   'overtime_pay': 2250.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 7050.0},
#  {'id': '2021017',
#   'hours_rendered': '18',
#   'monthly_fee': 6000,
#   'prorated_pay': 6000.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 6300.0},
#  {'id': '2021018',
#   'hours_rendered': '18',
#   'monthly_fee': 3500,
#   'prorated_pay': 2975.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3275.0},
#  {'id': '2021019',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4500.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4800.0},
#  {'id': '2021020',
#   'hours_rendered': '18',
#   'monthly_fee': 4500,
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4350.0}]

# %% [markdown]
# #### 3.2.4
#
# Looping through the new list variable **payroll**, generate an intern payslip print spool file for the month of July. The time logs (as illustrated above) may be found in the file **./section3/interns-timelog-july2021.csv**.
#
# The output must be saved in a file named **./output/interns-payslips-july2021.txt**. The output looks like the following:
#
# ```
# Payroll Date   : July 31, 2021
# ID             : 2021001
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 20
# ------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021002
# Monthly Fee       : 3500
# ------------------------------
# Hours Rendered : 17
# ------------------------------
# Prorated Pay   : 2975.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 3275.0
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021013
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 18
# ------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# Takehome Pay   : 4050.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021014
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 22
# ------------------------------
# Prorated Pay   : 4950.0
# Overtime Pay   : 900.0
# Takehome Pay   : 5400.0
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021019
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 20
# ------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021020
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 18
# ------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4350.0
#
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2020
# ID             : 2021009
# Base Pay       : 4,500
# ------------------------------
# Hours Rendered : 15
# Takehome Pay   : 3,375.00
# ...
#
# ```
#
# **VERY IMPORTANT:** If the intern does not have a WFH allowance arrangement, **DO NOT** print out the line 'WFH Allowance'!!! The company does not want interns to ask about that if they see that line since it will open a can of worms.

# %%
# CODE CELL

import csv

filename = "./output/interns-payslips-july2021.txt"
payroll_run_date = "July 31, 2021"



# CODE START

print_dict={'prorated_pay':'Prorated Pay','overtime_pay':'Overtime Pay','wfh_allowance':'WFH Allowance','takehome_pay':'Takehome Pay'}

with open(filename,'a') as intern:
    for i in interns_payroll:
        intern.write(f'''Payroll Date\t: {payroll_run_date}
ID\t\t: {i['id']}
Monthly Fee\t: {i['monthly_fee']}
------------------------------
Hours Rendered\t: {i['hours_rendered']}
------------------------------
''')
        for k,v in i.items():
            if k=='id' or k=='hours_rendered' or k=='monthly_fee':
                continue
            intern.write(f'''{print_dict[k]}\t: {v}
''')
        intern.write('''
______________________________
''')
        
# CODE END

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it.

# See the output of your file
# !cat ./output/interns-payslips-july2021.txt
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ### 3.3: For Consultants

# %% [markdown]
# Create a regular CSV named **./output/consultants_payouts_july2021.csv** containing consultant payout amounts. Use **./section3/consultants_masterlist.csv** as basis for the amounts, then don't forget to deduct 10% withholding tax.
#
# ```
# tin,net_pay
# 151-500-200-000,90000.00
# ...
# 151-500-202-000,100000.00
# ...
#
# ```

# %% [markdown]
# Create a dictionary **consultants_master_dict** containing lookups for consultants.

# %%
# CODE CELL

consultants_master_dict = {}
# CODE START
with open('./section3/consultants_masterlist.csv','r') as f:
    maslist=csv.DictReader(f)

    for r in maslist:
        consultants_master_dict[r['tin']]={'bank':r['bank'],'account_number':r['account_number']}
# CODE END
consultants_master_dict
# Out:
# {'151-500-200-000': {'bank': 'BPI', 'account_number': '1093 5000 6001'},
#  '151-500-201-000': {'bank': 'BPI', 'account_number': '1093 5000 6002'},
#  '151-500-202-000': {'bank': 'BDO', 'account_number': '0078 0000 0001'},
#  '151-500-203-000': {'bank': 'BPI', 'account_number': '1093 5000 6004'},
#  '151-500-204-000': {'bank': 'BPI', 'account_number': '1093 5000 6005'},
#  '151-500-205-000': {'bank': 'BPI', 'account_number': '1093 5000 6006'},
#  '151-500-206-000': {'bank': 'BDO', 'account_number': '0078 0000 0002'},
#  '151-500-207-000': {'bank': 'BDO', 'account_number': '0078 0000 0003'},
#  '151-500-208-000': {'bank': 'BPI', 'account_number': '1093 5000 6007'},
#  '151-500-209-000': {'bank': 'BPI', 'account_number': '1093 5000 6008'},
#  '151-500-210-000': {'bank': 'BPI', 'account_number': '1093 5000 6009'}}

# %% [markdown]
# Unlike the interns, we don't need to give consultants payslips. However, it would be easier to run "payroll" for consultants and store the results in a staging file. Run the consultants' "payroll" by keeping the results in a list variable called **consultants_payroll**. Each element of this list is based on a corresponding role in **./section3/consultants_masterlist.csv**. To make it easier, create a **consultants_fees** list variable by reading from this file.
#
# Then, generate a consultant payout file named **./output/consultants_payouts_july2021.csv**.

# %%
# CODE CELL


input_file = "./section3/consultants_masterlist.csv"
# CODE START

with open(input_file,'r') as csvfile:
    logs=csv.DictReader(csvfile)

    consultants_fees=[r for r in logs]
        
# CODE END

# dump output
consultants_fees
# Out:
# [{'tin': '151-500-200-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6001',
#   'monthly_fee': '100000',
#   'wfh': 'Y'},
#  {'tin': '151-500-201-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6002',
#   'monthly_fee': '50000',
#   'wfh': 'Y'},
#  {'tin': '151-500-202-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0001',
#   'monthly_fee': '111111.11',
#   'wfh': 'Y'},
#  {'tin': '151-500-203-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6004',
#   'monthly_fee': '100000',
#   'wfh': 'Y'},
#  {'tin': '151-500-204-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6005',
#   'monthly_fee': '65000',
#   'wfh': 'Y'},
#  {'tin': '151-500-205-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6006',
#   'monthly_fee': '130000',
#   'wfh': 'Y'},
#  {'tin': '151-500-206-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0002',
#   'monthly_fee': '50000',
#   'wfh': 'Y'},
#  {'tin': '151-500-207-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0003',
#   'monthly_fee': '45000',
#   'wfh': 'Y'},
#  {'tin': '151-500-208-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6007',
#   'monthly_fee': '45000',
#   'wfh': 'N'},
#  {'tin': '151-500-209-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6008',
#   'monthly_fee': '60000',
#   'wfh': 'N'},
#  {'tin': '151-500-210-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6009',
#   'monthly_fee': '45000',
#   'wfh': 'N'}]

# %%
# CODE CELL
consultants_payroll = []

# CODE START
for i in consultants_fees:
    indiv_dict={}
    indiv_dict['tin']=i['tin']
    indiv_dict['net_pay']=float(i['monthly_fee'])*0.9
    consultants_payroll.append(indiv_dict)

with open('./output/consultants_payouts_july2021.csv','w',newline="") as csvfile:
    field_names=['tin','net_pay']
    writer = csv.DictWriter(csvfile,fieldnames=field_names)
    writer.writeheader()
    for j in consultants_payroll:
        writer.writerow(j)
# CODE END

# sample dump of raw_log in interactive mode
consultants_payroll
# Out:
# [{'tin': '151-500-200-000', 'net_pay': 90000.0},
#  {'tin': '151-500-201-000', 'net_pay': 45000.0},
#  {'tin': '151-500-202-000', 'net_pay': 99999.999},
#  {'tin': '151-500-203-000', 'net_pay': 90000.0},
#  {'tin': '151-500-204-000', 'net_pay': 58500.0},
#  {'tin': '151-500-205-000', 'net_pay': 117000.0},
#  {'tin': '151-500-206-000', 'net_pay': 45000.0},
#  {'tin': '151-500-207-000', 'net_pay': 40500.0},
#  {'tin': '151-500-208-000', 'net_pay': 40500.0},
#  {'tin': '151-500-209-000', 'net_pay': 54000.0},
#  {'tin': '151-500-210-000', 'net_pay': 40500.0}]

# %% [markdown]
# To check if your payout file contents are correct, run `cat` (if using MacOS) or `type` (if using Windows). Don't forget the "!" character before the command. Replace `cat` with `type` if you are on Windows.

# %%
# !cat ./output/consultants_payouts_july2021.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ### 3.4: Bank Credit Advise

# %% [markdown]
# **B. Bank Credit Advise**
#
# Generate a credit advise file each for BPI and BDO covering interns and consultants. The files must be named **./output/su-bpi-payment-advise.csv** and **./output/su-bdo-payment-advise.csv** respectively and should look like the following:
#
# ```
# account_number,amount
# 109350005001,4800.0
# 109350005002,3275.0
# ...
# 109350005003,3375.0
# ...
# 109350006001,9000
# ```

# %%
# CODE CELL
bpi_advise = []
bdo_advise = []

# CODE START
for k,v in interns_master_dict.items():
    for i in interns_payroll:
        if v['bank']=='BPI' and i['id']==k:
            bpi_advise.append({'account_number': v['account_number'], 'amount':i['takehome_pay']})
        elif v['bank']=='BDO' and i['id']==k:
            bdo_advise.append({'account_number': v['account_number'], 'amount':i['takehome_pay']})
for k,v in consultants_master_dict.items():
    for i in consultants_payroll:
        if v['bank']=='BPI' and i['tin']==k:
            bpi_advise.append({'account_number': v['account_number'], 'amount':i['net_pay']})
        elif v['bank']=='BDO' and i['tin']==k:
            bdo_advise.append({'account_number': v['account_number'], 'amount':i['net_pay']})    

with open('./output/su-bpi-payment-advise.csv','w',newline="") as csvfile:
    field_names=['account_number','amount']
    writer = csv.DictWriter(csvfile,fieldnames=field_names)
    writer.writeheader()
    for r1 in bpi_advise:
        writer.writerow(r1)
        
with open('./output/su-bdo-payment-advise.csv','w',newline="") as csvfile:
    field_names=['account_number','amount']
    writer = csv.DictWriter(csvfile,fieldnames=field_names)
    writer.writeheader()
    for r2 in bdo_advise:
        writer.writerow(r2)
# CODE END

# %%
bpi_advise
# Out:
# [{'account_number': '1093 5000 5001', 'amount': 4800.0},
#  {'account_number': '1093 5000 5002', 'amount': 3275.0},
#  {'account_number': '1093 5000 5003', 'amount': 3900.0},
#  {'account_number': '1093 5000 5004', 'amount': 3675.0},
#  {'account_number': '1093 5000 5005', 'amount': 5100.0},
#  {'account_number': '1093 5000 5006', 'amount': 4350.0},
#  {'account_number': '1093 5000 5007', 'amount': 4550.0},
#  {'account_number': '1093 5000 5008', 'amount': 4125.0},
#  {'account_number': '1093 5000 5009', 'amount': 3375.0},
#  {'account_number': '1093 5000 5010', 'amount': 5400.0},
#  {'account_number': '1093 5000 5011', 'amount': 3600.0},
#  {'account_number': '1093 5000 5012', 'amount': 3500.0},
#  {'account_number': '1093 5000 5013', 'amount': 4050.0},
#  {'account_number': '1093 5000 5014', 'amount': 5400.0},
#  {'account_number': '1093 5000 5015', 'amount': 5300.0},
#  {'account_number': '1093 5000 5016', 'amount': 7050.0},
#  {'account_number': '1093 5000 5017', 'amount': 6300.0},
#  {'account_number': '1093 5000 5018', 'amount': 3275.0},
#  {'account_number': '1093 5000 5019', 'amount': 4800.0},
#  {'account_number': '1093 5000 5020', 'amount': 4350.0},
#  {'account_number': '1093 5000 6001', 'amount': 90000.0},
#  {'account_number': '1093 5000 6002', 'amount': 45000.0},
#  {'account_number': '1093 5000 6004', 'amount': 90000.0},
#  {'account_number': '1093 5000 6005', 'amount': 58500.0},
#  {'account_number': '1093 5000 6006', 'amount': 117000.0},
#  {'account_number': '1093 5000 6007', 'amount': 40500.0},
#  {'account_number': '1093 5000 6008', 'amount': 54000.0},
#  {'account_number': '1093 5000 6009', 'amount': 40500.0}]

# %%
bdo_advise
# Out:
# [{'account_number': '0078 0000 0001', 'amount': 99999.999},
#  {'account_number': '0078 0000 0002', 'amount': 45000.0},
#  {'account_number': '0078 0000 0003', 'amount': 40500.0}]

# %% [markdown]
# To check if your file outputs are correct, run either cat (on MacOS) or type (on Windows) below. Just replace `cat` with `type` if you're using Windows.

# %%
# !cat ./output/su-bpi-payment-advise.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !cat ./output/su-bdo-payment-advise.csv
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.
